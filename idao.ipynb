# %%
from keras.layers import Input, Flatten, Dense
from keras.models import Model

# %%
input_layer = Input(shape=(576,576))
x = Flatten()(input_layer)
x = Dense(units=200, activation = 'relu')(x)
#x = Dense(units=150, activation = 'relu')(x)
output_layer = Dense(units=3, activation = 'softmax')(x)
model = Model(input_layer, output_layer)

# %%
from matplotlib import image
import os

def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = image.imread(os.path.join(folder,filename))
        if img is not None:
            images.append(img)
    return images
folder="/home/aleksandr/Downloads/track_1/idao_dataset/train/ER"

# %%
import numpy as np

# %%
images = load_images_from_folder(folder)
print(len(images))
# Out:
# 6758

# %%
images[0]
# Out:
# array([[0.39215687, 0.3764706 , 0.38431373, ..., 0.40392157, 0.3764706 ,
#         0.38039216],
#        [0.39215687, 0.38039216, 0.38039216, ..., 0.38431373, 0.40784314,
#         0.4       ],
#        [0.39607844, 0.3882353 , 0.39607844, ..., 0.38431373, 0.39607844,
#         0.3764706 ],
#        ...,
#        [0.39215687, 0.3882353 , 0.39607844, ..., 0.3764706 , 0.4       ,
#         0.40784314],
#        [0.39607844, 0.38039216, 0.3882353 , ..., 0.42352942, 0.3764706 ,
#         0.4       ],
#        [0.35686275, 0.39607844, 0.3882353 , ..., 0.3882353 , 0.4117647 ,
#         0.39215687]], dtype=float32)

# %%
from matplotlib import pyplot as plt
plt.imshow(images[0])

# %%
images = np.array(images)

# %%
from keras.optimizers import Adam
opt = Adam(lr=0.0005)
model.compile(loss='categorical_crossentropy', optimizer=opt,metrics=['accuracy'])

# %%
(x_train, y_train), (x_test, y_test) = (0,0),(0,0)

# %%
import numpy as np
from keras.utils import to_categorical

# %%
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
#model.fit(x_train, y_train, batch_size = 32, epochs = 10, shuffle = True)

# %%
#preds = model.predict(x_test) 
#print(preds)
